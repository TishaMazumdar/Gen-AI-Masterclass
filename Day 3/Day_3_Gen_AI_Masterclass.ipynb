# %% [markdown]
# <a href="https://colab.research.google.com/github/TishaMazumdar/Gen-AI-Masterclass/blob/main/Day_3_Gen_AI_Masterclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Essential Linear Algebra Concepts

# %%
import numpy as np

# %%
# Vectors
v1 = np.array([1,2,3])
v2 = np.array([4,5,6])

v_add = v1 + v2
v_sub = v1 - v2
print('Vector Addition:',v_add)
print('Vector Subtraction:',v_sub)
# Out:
# Vector Addition: [5 7 9]
# Vector Subtraction: [-3 -3 -3]

# %%
# Scalar multiplication

v_scalar = 3 * v1
print('Scalar Multiplication:',v_scalar)
# Out:
# Scalar Multiplication: [3 6 9]

# %%
# Matrices

m1 = np.array([[1,2],[3,4]])
m2 = np.array([[5,6],[7,8]])

m_add = m1 + m2
m_sub = m1 - m2
print('Matrix Addition:\n',m_add)
print('Matrix Subtraction:\n',m_sub)
# Out:
# Matrix Addition:
#  [[ 6  8]
#  [10 12]]
# Matrix Subtraction:
#  [[-4 -4]
#  [-4 -4]]

# %%
# Matrix Multiplication

m_mult = np.dot(m1,m2)
print('Matrix Multiplication:\n',m_mult)
# Out:
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]

# %%
# Dot Product

dot_prod = np.dot(v1,v2)
print('Dot Product:',dot_prod)
# Out:
# Dot Product: 32

# %% [markdown]
# # Gradient Descent Optimization

# %%
import matplotlib.pyplot as plt

# %%
def f(x):
  return x**2

def gradiennt(x):
  return 2*x

# %%
# Gradient Descent Parameters

x = 10
learning_rate = 0.1
iterations = 20

# %%
# Lists to store the values for plotting
x_values = [x]
f_values = [f(x)]

# %%
for _ in range(iterations):
  grad = gradiennt(x)
  x = x - learning_rate * grad
  x_values.append(x)
  f_values.append(f(x))

# %%
# Plot the function path and optimization path

x_range = np.linspace(-10,10,400)
plt.plot(x_range,f(x_range),label='$f(x) = x^2$')
plt.scatter(x_values,f_values,color='red',label='Gradient Descent Path')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gradient Descent Optimization')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Hands On Project

# %% [markdown]
# f(x) = (x-3)^2 + 4

# %%
def f(x):
  return (x-3)**2 + 4

def gradient(x):
  return 2*(x-3)

# Gradient descent parameters
initial_values = [10,-10,5,-5]
learning_rate = 0.1
iterations = 20

# Plot the function
x_range = np.linspace(-10,10,400)
plt.plot(x_range,f(x_range),label='$f(x) = (x-3)^2 + 4$')

for x in initial_values:
  x_values = [x]
  f_values = [f(x)]
  for _ in range(iterations):
    grad = gradient(x)
    x = x - learning_rate * grad
    x_values.append(x)
    f_values.append(f(x))
  plt.scatter(x_values,f_values,label=f'Path from initial x={x_values[0]}')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.title('Gradient Descent Optimization from Different Initial Values')
plt.legend()
plt.grid(True)
plt.show()
